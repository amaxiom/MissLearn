# %% [markdown]
# # MissLearn Testing Suite

# %% [markdown]
# ### Unit Testing
#
# Each cell below runs one test class independently.
# Run a single cell to test one component, or **Run All** to execute the full suite.
#
# | # | Class | What it covers |
# |---|-------|----------------|
# | 1 | TestNumericalUtils | `_utils`: pack_cholesky, mvn_logpdf, conditional_normal, numerical_hessian |
# | 2 | TestMissLinear | FIML joint multivariate normal regression |
# | 3 | TestMissLogistic | FIML logistic regression |
# | 4 | TestMissRidgeRegressor | Ridge-penalized FIML regressor |
# | 5 | TestMissRidgeClassifier | Ridge-penalized FIML classifier |
# | 6 | TestMissRidge | Auto-task selector wrapper |
# | 7 | TestMissLASSO | LASSO FIML (regressor / classifier / auto) |
# | 8 | TestMissNeighbors | K-nearest neighbours FIML |
# | 9 | TestMissBayes | Naive Bayes FIML |
# | 10 | TestMissSupport | Support vector FIML |
# | 11 | TestMissGaussian | Gaussian Process FIML (small n) |
# | 12 | TestMissMixed | Mixed-effects / LME FIML |
# | 13 | TestMissEnsemble | Bootstrap-aggregated ensemble |
# | 14 | TestMissMulticlass | One-vs-Rest multi-class extension |
# | 15 | TestMissPreprocessor | Validation, compatibility checking, categorical encoding |
# | 16 | TestMissDiagnostic | Missing data mechanism diagnostics |
# | 17 | TestMissKFold | K-fold splitter (NaN-safe) |
# | 18 | TestMissStratifiedKFold | Stratified K-fold splitter |
# | 19 | TestCrossVal | `miss_cross_val_score` / `miss_cross_validate` |
# | 20 | TestMissImputer | Multiple imputation via joint MVN |
# | 21 | TestMissSensitivity | MNAR delta-adjustment sensitivity analysis |
# | 22 | TestMissShapley | Low-level Shapley engine (exact + kernel) |
# | 23 | TestMissExplainer | High-level SHAP explainability interface |
# | 24 | TestPandasSupport | DataFrame / Series integration |
# | 25 | TestCopulaTransform | Marginal Gaussian copula option |

# %%
# Setup: run this cell first
import os, sys, pytest

# Set working directory to tests/ so relative pytest paths resolve correctly
os.chdir(r"C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests")

print("Working directory:", os.getcwd())
print("Ready.  Run any cell below to execute that test class.")
print()
print("To run the entire suite at once:")
print("  pytest.main(['-v', '--tb=short', 'unit_test_suite.py'])")
# Out:
# Working directory: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# Ready.  Run any cell below to execute that test class.
#
# To run the entire suite at once:
#   pytest.main(['-v', '--tb=short', 'unit_test_suite.py'])

# %% [markdown]
# ---
# ### 1. TestNumericalUtils
# `_utils`: `pack_cholesky` / `unpack_cholesky` round-trip, `mvn_logpdf`, `conditional_normal_params`, `numerical_hessian`

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestNumericalUtils'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 8 items
#
# unit_test_suite.py::TestNumericalUtils::test_pack_unpack_cholesky_roundtrip PASSED                               [ 12%]
# unit_test_suite.py::TestNumericalUtils::test_pack_cholesky_diagonal_positive PASSED                              [ 25%]
# unit_test_suite.py::TestNumericalUtils::test_mvn_logpdf_scalar PASSED                                            [ 37%]
# unit_test_suite.py::TestNumericalUtils::test_mvn_logpdf_batch_equals_scalar PASSED                               [ 50%]
# unit_test_suite.py::TestNumericalUtils::test_conditional_normal_params_shape PASSED                              [ 62%]
# ...

# %% [markdown]
# ---
# ### 2. TestMissLinear
# FIML joint multivariate-normal regression (`MissLinear`): coefficients, standard errors, log-likelihood, prediction intervals, NaN handling in X and y.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissLinear'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 15 items
#
# unit_test_suite.py::TestMissLinear::test_attributes_set_after_fit PASSED                                         [  6%]
# unit_test_suite.py::TestMissLinear::test_coef_shape PASSED                                                       [ 13%]
# unit_test_suite.py::TestMissLinear::test_se_finite PASSED                                                        [ 20%]
# unit_test_suite.py::TestMissLinear::test_coef_direction PASSED                                                   [ 26%]
# unit_test_suite.py::TestMissLinear::test_predict_shape PASSED                                                    [ 33%]
# ...

# %% [markdown]
# ---
# ### 3. TestMissLogistic
# FIML logistic regression (`MissLogistic`): probability outputs, class labels, AUC above chance, coefficient direction.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissLogistic'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 8 items
#
# unit_test_suite.py::TestMissLogistic::test_attributes PASSED                                                     [ 12%]
# unit_test_suite.py::TestMissLogistic::test_predict_proba_shape PASSED                                            [ 25%]
# unit_test_suite.py::TestMissLogistic::test_predict_proba_sums_to_one PASSED                                      [ 37%]
# unit_test_suite.py::TestMissLogistic::test_predict_proba_in_unit_interval PASSED                                 [ 50%]
# unit_test_suite.py::TestMissLogistic::test_predict_returns_classes PASSED                                        [ 62%]
# ...

# %% [markdown]
# ---
# ### 4. TestMissRidgeRegressor
# Ridge-penalized FIML regressor (`MissRidgeRegressor`): unpenalized log-likelihood (fix #25), SE shapes, prediction intervals, alpha=0 near-equivalence to MissLinear.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissRidgeRegressor'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 12 items
#
# unit_test_suite.py::TestMissRidgeRegressor::test_attributes PASSED                                               [  8%]
# unit_test_suite.py::TestMissRidgeRegressor::test_coef_shape PASSED                                               [ 16%]
# unit_test_suite.py::TestMissRidgeRegressor::test_se_shape PASSED                                                 [ 25%]
# unit_test_suite.py::TestMissRidgeRegressor::test_se_positive PASSED                                              [ 33%]
# unit_test_suite.py::TestMissRidgeRegressor::test_loglik_unpenalized PASSED                                       [ 41%]
# ...

# %% [markdown]
# ---
# ### 5. TestMissRidgeClassifier
# Ridge-penalized FIML binary classifier (`MissRidgeClassifier`): probability sums, binary predictions, score above chance, coefficient direction.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissRidgeClassifier'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 5 items
#
# unit_test_suite.py::TestMissRidgeClassifier::test_attributes PASSED                                              [ 20%]
# unit_test_suite.py::TestMissRidgeClassifier::test_predict_proba_sums_to_one PASSED                               [ 40%]
# unit_test_suite.py::TestMissRidgeClassifier::test_predict_returns_binary PASSED                                  [ 60%]
# unit_test_suite.py::TestMissRidgeClassifier::test_score_above_chance PASSED                                      [ 80%]
# unit_test_suite.py::TestMissRidgeClassifier::test_coef_direction PASSED                                          [100%]
#
# ...

# %% [markdown]
# ---
# ### 6. TestMissRidge
# Auto-task wrapper (`MissRidge`): task detection, delegation to regressor/classifier, `get_params`/`set_params`, guard against calling wrong interface.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissRidge'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 8 items
#
# unit_test_suite.py::TestMissRidge::test_regression_task_detected PASSED                                          [ 12%]
# unit_test_suite.py::TestMissRidge::test_classification_task_detected PASSED                                      [ 25%]
# unit_test_suite.py::TestMissRidge::test_regression_predict_finite PASSED                                         [ 37%]
# unit_test_suite.py::TestMissRidge::test_classification_predict_proba_valid PASSED                                [ 50%]
# unit_test_suite.py::TestMissRidge::test_predict_proba_unavailable_for_regression PASSED                          [ 62%]
# ...

# %% [markdown]
# ---
# ### 7. TestMissLASSO
# LASSO FIML models (`MissLASSORegressor`, `MissLASSOClassifier`, `MissLASSO`): sparse coefficients, strong-penalty shrinkage, auto task detection.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissLASSO'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 6 items
#
# unit_test_suite.py::TestMissLASSO::test_regressor_fit_predict PASSED                                             [ 16%]
# unit_test_suite.py::TestMissLASSO::test_regressor_score_positive PASSED                                          [ 33%]
# unit_test_suite.py::TestMissLASSO::test_classifier_proba_valid PASSED                                            [ 50%]
# unit_test_suite.py::TestMissLASSO::test_auto_regression PASSED                                                   [ 66%]
# unit_test_suite.py::TestMissLASSO::test_auto_classification PASSED                                               [ 83%]
# ...

# %% [markdown]
# ---
# ### 8. TestMissNeighbors
# K-nearest neighbours FIML (`MissNeighbors`): regression and classification, all-missing row still returns finite prediction, auto task detection.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissNeighbors'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 6 items
#
# unit_test_suite.py::TestMissNeighbors::test_regressor_fit_predict PASSED                                         [ 16%]
# unit_test_suite.py::TestMissNeighbors::test_regressor_score_positive PASSED                                      [ 33%]
# unit_test_suite.py::TestMissNeighbors::test_classifier_proba_valid PASSED                                        [ 50%]
# unit_test_suite.py::TestMissNeighbors::test_classifier_score_above_chance PASSED                                 [ 66%]
# unit_test_suite.py::TestMissNeighbors::test_auto_task_detection PASSED                                           [ 83%]
# ...

# %% [markdown]
# ---
# ### 9. TestMissBayes
# Naive Bayes FIML (`MissBayes`): regressor and classifier predictions, auto task detection.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissBayes'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 3 items
#
# unit_test_suite.py::TestMissBayes::test_regressor_fit_predict PASSED                                             [ 33%]
# unit_test_suite.py::TestMissBayes::test_classifier_proba_valid PASSED                                            [ 66%]
# unit_test_suite.py::TestMissBayes::test_auto_task PASSED                                                         [100%]
#
# ================================================== 3 passed in 0.05s ==================================================
# <ExitCode.OK: 0>

# %% [markdown]
# ---
# ### 10. TestMissSupport
# Support vector FIML (`MissSupport`): regressor and classifier, auto task detection.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissSupport'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 3 items
#
# unit_test_suite.py::TestMissSupport::test_regressor_fit_predict PASSED                                           [ 33%]
# unit_test_suite.py::TestMissSupport::test_classifier_proba_valid PASSED                                          [ 66%]
# unit_test_suite.py::TestMissSupport::test_auto_task PASSED                                                       [100%]
#
# ================================================== 3 passed in 0.12s ==================================================
# <ExitCode.OK: 0>

# %% [markdown]
# ---
# ### 11. TestMissGaussian
# Gaussian Process FIML (`MissGaussian`, small n): regressor prediction intervals, interval width increases with missingness, classifier probabilities.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissGaussian'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 4 items
#
# unit_test_suite.py::TestMissGaussian::test_regressor_fit_predict PASSED                                          [ 25%]
# unit_test_suite.py::TestMissGaussian::test_regressor_predict_interval PASSED                                     [ 50%]
# unit_test_suite.py::TestMissGaussian::test_regressor_interval_wider_for_missing PASSED                           [ 75%]
# unit_test_suite.py::TestMissGaussian::test_classifier_proba_valid PASSED                                         [100%]
#
# ================================================== 4 passed in 0.68s ==================================================
# ...

# %% [markdown]
# ---
# ### 12. TestMissMixed
# Mixed-effects / LME FIML (`MissMixedRegressor`, `MissMixedClassifier`, `MissMixed`): BLUPs stored after fit, classifier probabilities, auto task detection.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissMixed'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 4 items
#
# unit_test_suite.py::TestMissMixed::test_regressor_fit_predict PASSED                                             [ 25%]
# unit_test_suite.py::TestMissMixed::test_regressor_random_effects_stored PASSED                                   [ 50%]
# unit_test_suite.py::TestMissMixed::test_classifier_fit_predict PASSED                                            [ 75%]
# unit_test_suite.py::TestMissMixed::test_auto_task_mixed PASSED                                                   [100%]
#
# ================================================= 4 passed in 46.55s ==================================================
# ...

# %% [markdown]
# ---
# ### 13. TestMissEnsemble
# Bootstrap-aggregated ensemble (`MissEnsemble`): regression and classification, prediction intervals, OOB score, heterogeneous base estimators, `classes_` derived from y (fix #20).

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissEnsemble'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 11 items
#
# unit_test_suite.py::TestMissEnsemble::test_regression_predict_shape PASSED                                       [  9%]
# unit_test_suite.py::TestMissEnsemble::test_regression_predict_interval PASSED                                    [ 18%]
# unit_test_suite.py::TestMissEnsemble::test_regression_score_positive PASSED                                      [ 27%]
# unit_test_suite.py::TestMissEnsemble::test_classification_predict_proba_valid PASSED                             [ 36%]
# unit_test_suite.py::TestMissEnsemble::test_classification_score_above_chance PASSED                              [ 45%]
# ...

# %% [markdown]
# ---
# ### 14. TestMissMulticlass
# One-vs-Rest multi-class extension (`MissMulticlass`): K-class probability shape, rows sum to 1, `predict()` labels, `get_params`/`set_params`, `decision_function`, `score()`, `summary()`.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissMulticlass'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 7 items
#
# unit_test_suite.py::TestMissMulticlass::test_n_classes PASSED                                                    [ 14%]
# unit_test_suite.py::TestMissMulticlass::test_classes PASSED                                                      [ 28%]
# unit_test_suite.py::TestMissMulticlass::test_predict_proba_shape PASSED                                          [ 42%]
# unit_test_suite.py::TestMissMulticlass::test_predict_proba_sums_to_one PASSED                                    [ 57%]
# unit_test_suite.py::TestMissMulticlass::test_predict_returns_known_classes PASSED                                [ 71%]
# ...

# %% [markdown]
# ---
# ### 15. TestMissPreprocessor
# Validation and preprocessing (`MissValidator`, `MissPreprocessor`): all-NaN column rejection, constant column rejection, numeric passthrough, categorical one-hot encoding, NaN preservation after encoding.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissPreprocessor'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 7 items
#
# unit_test_suite.py::TestMissPreprocessor::test_prefit_check_passes_clean_data PASSED                             [ 14%]
# unit_test_suite.py::TestMissPreprocessor::test_prefit_check_all_nan_column_is_error PASSED                       [ 28%]
# unit_test_suite.py::TestMissPreprocessor::test_prefit_check_constant_column_is_error PASSED                      [ 42%]
# unit_test_suite.py::TestMissPreprocessor::test_preprocessor_passthrough_numeric PASSED                           [ 57%]
# unit_test_suite.py::TestMissPreprocessor::test_preprocessor_categorical_encoding PASSED                          [ 71%]
# ...

# %% [markdown]
# ---
# ### 16. TestMissDiagnostic
# Missing data mechanism diagnostics (`miss_little_mcar`, `miss_mar_plausibility`, `miss_pattern_summary`): test statistic sign, p-value range, pattern coverage.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissDiagnostic'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 8 items
#
# unit_test_suite.py::TestMissDiagnostic::test_little_mcar_keys PASSED                                             [ 12%]
# unit_test_suite.py::TestMissDiagnostic::test_little_mcar_pvalue_in_unit_interval PASSED                          [ 25%]
# unit_test_suite.py::TestMissDiagnostic::test_little_mcar_statistic_nonneg PASSED                                 [ 37%]
# unit_test_suite.py::TestMissDiagnostic::test_mar_plausibility_returns_dict PASSED                                [ 50%]
# unit_test_suite.py::TestMissDiagnostic::test_mar_plausibility_pvalues_valid PASSED                               [ 62%]
# ...

# %% [markdown]
# ---
# ### 17. TestMissKFold
# NaN-safe K-fold splitter (`MissKFold`): correct fold sizes, no overlap between train/test, all indices covered.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissKFold'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 7 items
#
# unit_test_suite.py::TestMissKFold::test_fold_count PASSED                                                        [ 14%]
# unit_test_suite.py::TestMissKFold::test_full_coverage PASSED                                                     [ 28%]
# unit_test_suite.py::TestMissKFold::test_no_overlap PASSED                                                        [ 42%]
# unit_test_suite.py::TestMissKFold::test_correct_sizes PASSED                                                     [ 57%]
# unit_test_suite.py::TestMissKFold::test_shuffle_changes_assignment PASSED                                        [ 71%]
# ...

# %% [markdown]
# ---
# ### 18. TestMissStratifiedKFold
# Stratified K-fold splitter (`MissStratifiedKFold`): class balance preserved per fold, all indices covered.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissStratifiedKFold'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 4 items
#
# unit_test_suite.py::TestMissStratifiedKFold::test_full_coverage PASSED                                           [ 25%]
# unit_test_suite.py::TestMissStratifiedKFold::test_nan_y_distributed PASSED                                       [ 50%]
# unit_test_suite.py::TestMissStratifiedKFold::test_class_balance_maintained PASSED                                [ 75%]
# unit_test_suite.py::TestMissStratifiedKFold::test_random_state_reproducible PASSED                               [100%]
#
# ================================================== 4 passed in 0.06s ==================================================
# ...

# %% [markdown]
# ---
# ### 19. TestCrossVal
# `miss_cross_val_score` and `miss_cross_validate`: score array shape, RÂ² > 0, multiple metrics, DataFrame/ndarray equivalence with matching `random_state`.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestCrossVal'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 8 items
#
# unit_test_suite.py::TestCrossVal::test_cross_val_score_shape PASSED                                              [ 12%]
# unit_test_suite.py::TestCrossVal::test_cross_val_score_finite PASSED                                             [ 25%]
# unit_test_suite.py::TestCrossVal::test_cross_val_named_scoring PASSED                                            [ 37%]
# unit_test_suite.py::TestCrossVal::test_cross_val_random_state_reproducible PASSED                                [ 50%]
# unit_test_suite.py::TestCrossVal::test_cross_validate_keys PASSED                                                [ 62%]
# ...

# %% [markdown]
# ---
# ### 20. TestMissImputer
# Multiple imputation via joint MVN (`MissImputer`): imputed shape, no NaN in output, Rubin's-rules pooled estimates, between/within imputation variance.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissImputer'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 13 items
#
# unit_test_suite.py::TestMissImputer::test_attributes_after_fit PASSED                                            [  7%]
# unit_test_suite.py::TestMissImputer::test_mu_shape PASSED                                                        [ 15%]
# unit_test_suite.py::TestMissImputer::test_sigma_positive_definite PASSED                                         [ 23%]
# unit_test_suite.py::TestMissImputer::test_transform_returns_m_datasets PASSED                                    [ 30%]
# unit_test_suite.py::TestMissImputer::test_transform_no_nan PASSED                                                [ 38%]
# ...

# %% [markdown]
# ---
# ### 21. TestMissSensitivity
# MNAR delta-adjustment sensitivity analysis (`MissSensitivity`): coefficient curves over delta grid, sensitivity table shape, delta=0 recovers base model.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissSensitivity'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 8 items
#
# unit_test_suite.py::TestMissSensitivity::test_coef_curves_shape PASSED                                           [ 12%]
# unit_test_suite.py::TestMissSensitivity::test_delta_grid_shape PASSED                                            [ 25%]
# unit_test_suite.py::TestMissSensitivity::test_sensitivity_table_shape PASSED                                     [ 37%]
# unit_test_suite.py::TestMissSensitivity::test_tipping_point_returns_float_or_none PASSED                         [ 50%]
# unit_test_suite.py::TestMissSensitivity::test_verdict_returns_string PASSED                                      [ 62%]
# ...

# %% [markdown]
# ---
# ### 22. TestMissShapley
# Low-level Shapley engine (`MissShapley`): exact SHAP efficiency property (sum = f(x) - baseline), KernelSHAP shape, missingness SHAP shape, baseline fallback.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissShapley'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 7 items
#
# unit_test_suite.py::TestMissShapley::test_exact_shap_shape PASSED                                                [ 14%]
# unit_test_suite.py::TestMissShapley::test_exact_shap_finite PASSED                                               [ 28%]
# unit_test_suite.py::TestMissShapley::test_efficiency_fully_observed_rows PASSED                                  [ 42%]
# unit_test_suite.py::TestMissShapley::test_nan_features_get_zero_phi PASSED                                       [ 57%]
# unit_test_suite.py::TestMissShapley::test_kernel_shap_shape PASSED                                               [ 71%]
# ...

# %% [markdown]
# ---
# ### 23. TestMissExplainer
# High-level SHAP interface (`MissExplainer`): `explain()` shape, waterfall/bar/beeswarm/dependence plots return `(fig, ax)`, plot titles, interaction-coloured dependence.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestMissExplainer'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 19 items
#
# unit_test_suite.py::TestMissExplainer::test_expected_value_finite PASSED                                         [  5%]
# unit_test_suite.py::TestMissExplainer::test_feature_names_set PASSED                                             [ 10%]
# unit_test_suite.py::TestMissExplainer::test_p_set PASSED                                                         [ 15%]
# unit_test_suite.py::TestMissExplainer::test_shap_values_shape PASSED                                             [ 21%]
# unit_test_suite.py::TestMissExplainer::test_shap_values_finite PASSED                                            [ 26%]
# ...

# %% [markdown]
# ---
# ### 24. TestPandasSupport
# DataFrame / Series integration: fit on DataFrame, predict on ndarray (and vice versa), `feature_names_in_` set from column names, NaN values preserved, score accepts DataFrames.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestPandasSupport'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 7 items
#
# unit_test_suite.py::TestPandasSupport::test_ridge_feature_names_from_dataframe PASSED                            [ 14%]
# unit_test_suite.py::TestPandasSupport::test_ridge_predict_dataframe_matches_ndarray PASSED                       [ 28%]
# unit_test_suite.py::TestPandasSupport::test_linear_feature_names_from_dataframe PASSED                           [ 42%]
# unit_test_suite.py::TestPandasSupport::test_mixed_fit_ndarray_predict_dataframe PASSED                           [ 57%]
# unit_test_suite.py::TestPandasSupport::test_nan_in_dataframe_preserved PASSED                                    [ 71%]
# ...

# %% [markdown]
# ---
# ### 25. TestCopulaTransform
# Marginal Gaussian copula option (`copula=True`, `copula='auto'`): fit/predict runs without error, finite predictions with missing X, classifier probabilities valid for skewed data.

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py::TestCopulaTransform'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 5 items
#
# unit_test_suite.py::TestCopulaTransform::test_copula_true_runs PASSED                                            [ 20%]
# unit_test_suite.py::TestCopulaTransform::test_copula_auto_runs PASSED                                            [ 40%]
# unit_test_suite.py::TestCopulaTransform::test_copula_predict_finite_with_missing PASSED                          [ 60%]
# unit_test_suite.py::TestCopulaTransform::test_copula_classifier_runs PASSED                                      [ 80%]
# unit_test_suite.py::TestCopulaTransform::test_copula_results_finite_for_skewed_data PASSED                       [100%]
#
# ...

# %% [markdown]
# ---
# ### Run the full suite

# %%
pytest.main(['-v', '--tb=short', 'unit_test_suite.py'])
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Amanda\Favorites\Machine Learning\MissLearn\tests
# plugins: anyio-3.5.0
# collecting ... collected 193 items
#
# unit_test_suite.py::TestNumericalUtils::test_pack_unpack_cholesky_roundtrip PASSED                               [  0%]
# unit_test_suite.py::TestNumericalUtils::test_pack_cholesky_diagonal_positive PASSED                              [  1%]
# unit_test_suite.py::TestNumericalUtils::test_mvn_logpdf_scalar PASSED                                            [  1%]
# unit_test_suite.py::TestNumericalUtils::test_mvn_logpdf_batch_equals_scalar PASSED                               [  2%]
# unit_test_suite.py::TestNumericalUtils::test_conditional_normal_params_shape PASSED                              [  2%]
# ...
